# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use(['ggplot'])

# from sklearn.naive_bayes import GaussianNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler, LabelEncoder

import pandas_profiling
from sklearn.model_selection import train_test_split

import pickle

# %%
df_train = pd.read_csv("dataset/house/train.csv")
df_test = pd.read_csv("dataset/house/test.csv")

report = df_train.profile_report(title="House Prices")

display(df_train)
display(df_test)

print(df_train.shape)
print(df_test.shape)

display(df_train.info())
display(df_test.info())
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print(df_train.columns)
print(df_test.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print(df_train.isnull().sum().sum())
print(df_test.isnull().sum().sum())
# Out:
# 6965
# 7000

# %%
# df_house = df_train[['MSSubClass','LotArea','YrSold', 'SalePrice','PoolArea','MoSold']] # Pool Area and Month Sale
# features = df_train[['MSSubClass','LotArea','YrSold']]
# target = df_train['SalePrice']
# features.info()
# target.info()

# %%
df_mszoning = df_train['MSZoning']
df_street = df_train['Street']
df_lotshape = df_train['LotShape']
df_landcontour = df_train['LandContour']
df_poolarea = df_train['PoolArea']
df_salecondition = df_train['SaleCondition']

le = LabelEncoder()

mszoning_en = le.fit_transform(df_mszoning)
print("MSZoning",le.classes_)
street_en = le.fit_transform(df_street)
print("Street",le.classes_)
lotshape_en = le.fit_transform(df_lotshape)
print("LotShape",le.classes_)
landcontour_en = le.fit_transform(df_landcontour)
print("LandContour",le.classes_)
salecondition_en = le.fit_transform(df_salecondition)
print("SaleCondition",le.classes_)

df = pd.DataFrame({"MSSubClass":df_train['MSSubClass'],"MSZoning":mszoning_en,"LotArea":df_train['LotArea'],"Street":street_en,"LotShape":lotshape_en,"LandContour":landcontour_en,"PoolArea":df_train['PoolArea'],"MoSold":df_train['MoSold'],"YrSold":df_train['YrSold'],"SaleCondition":salecondition_en,"SalePrice":df_train['SalePrice']})
df
# Out:
# MSZoning ['C (all)' 'FV' 'RH' 'RL' 'RM']
# Street ['Grvl' 'Pave']
# LotShape ['IR1' 'IR2' 'IR3' 'Reg']
# LandContour ['Bnk' 'HLS' 'Low' 'Lvl']
# SaleCondition ['Abnorml' 'AdjLand' 'Alloca' 'Family' 'Normal' 'Partial']
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  PoolArea  \
# 0             60         3     8450       1         3            3         0
# 1             20         3     9600       1         3            3         0
# 2             60         3    11250       1         0            3         0
# 3             70         3     9550       1         0            3         0
# 4             60         3    14260       1         0            3         0
# ...          ...       ...      ...     ...       ...          ...       ...
# 1455          60         3     7917       1         3            3         0
# 1456          20         3    13175       1         3            3         0
# ...

# %%
df_house = df#[['MSSubClass','MSZoning','LotArea','Street','LotShape','LandContour','PoolArea','MoSold','YrSold','SaleCondition','SalePrice']]
features = df[['MSSubClass','MSZoning','LotArea','Street','LotShape','LandContour','PoolArea','MoSold','YrSold','SaleCondition']]
target = df['SalePrice']
features.info()
target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   int32
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   int32
#  4   LotShape       1460 non-null   int32
#  5   LandContour    1460 non-null   int32
#  6   PoolArea       1460 non-null   int64
#  7   MoSold         1460 non-null   int64
#  8   YrSold         1460 non-null   int64
#  9   SaleCondition  1460 non-null   int32
# dtypes: int32(5), int64(5)
# memory usage: 85.7 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: SalePrice
# Non-Null Count  Dtype
# --------------  -----
# 1460 non-null   int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
df_house
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  PoolArea  \
# 0             60         3     8450       1         3            3         0
# 1             20         3     9600       1         3            3         0
# 2             60         3    11250       1         0            3         0
# 3             70         3     9550       1         0            3         0
# 4             60         3    14260       1         0            3         0
# ...          ...       ...      ...     ...       ...          ...       ...
# 1455          60         3     7917       1         3            3         0
# 1456          20         3    13175       1         3            3         0
# 1457          70         3     9042       1         3            3         0
# 1458          20         3     9717       1         3            3         0
# 1459          20         3     9937       1         3            3         0
#
# ...

# %%
features = df[['MSSubClass','MSZoning','LotArea','Street','LotShape','LandContour','PoolArea','MoSold','YrSold','SaleCondition']]
target = df['SalePrice']

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=0)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1022, 10) (438, 10)
# (1022,) (438,)

# %%
scaler = MinMaxScaler()
le = LabelEncoder()

# %%
scaler.fit_transform(features)
# Out:
# array([[0.23529412, 0.75      , 0.0334198 , ..., 0.09090909, 0.5       ,
#         0.8       ],
#        [0.        , 0.75      , 0.03879502, ..., 0.36363636, 0.25      ,
#         0.8       ],
#        [0.23529412, 0.75      , 0.04650728, ..., 0.72727273, 0.5       ,
#         0.8       ],
#        ...,
#        [0.29411765, 0.75      , 0.03618687, ..., 0.36363636, 1.        ,
#         0.8       ],
#        [0.        , 0.75      , 0.03934189, ..., 0.27272727, 1.        ,
#         0.8       ],
#        [0.        , 0.75      , 0.04037019, ..., 0.45454545, 0.5       ,
#         0.8       ]])

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target)

print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1095, 10) (365, 10)
# (1095,) (365,)

# %%
model = LinearRegression().fit(x_train, y_train)

# %%
model.predict([[20, 3, 10000, 1, 3, 3, 20, 7, 2016, 4]])
# Out:
# C:\Users\imans\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([163782.08469912])

# %%
model.score(x_test, y_test)
# Out:
# 0.17692244032130477

# %%
pickle.dump(model, open('model_houseprices.pkl', 'wb'))

# %%
features
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  PoolArea  \
# 0             60         3     8450       1         3            3         0
# 1             20         3     9600       1         3            3         0
# 2             60         3    11250       1         0            3         0
# 3             70         3     9550       1         0            3         0
# 4             60         3    14260       1         0            3         0
# ...          ...       ...      ...     ...       ...          ...       ...
# 1455          60         3     7917       1         3            3         0
# 1456          20         3    13175       1         3            3         0
# 1457          70         3     9042       1         3            3         0
# 1458          20         3     9717       1         3            3         0
# 1459          20         3     9937       1         3            3         0
#
#       MoSold  YrSold  SaleCondition
# ...

# %%
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64
